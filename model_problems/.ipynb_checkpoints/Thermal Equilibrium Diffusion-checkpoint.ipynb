# %%
import string
import pandas as pd

# %% [markdown]
# # Model Equations

# %% [markdown]
# ## Marshak Solution

# %%
xraw = []
traw = []
with open("thermal_eq_diff/1.0sh") as f:
    for line in f:
        x,t = line.split()
        xraw.append(string.atof(x))
        traw.append(string.atof(t))
        
x = np.array(xraw)
T = np.array(traw)
plt.plot(x, T)
plt.xlabel("$x$ (cm)")
plt.ylabel("$T$ (keV)")
plt.title("Marshak Wave at 10 ns")
plt.xlim((0.0, 0.3))
# Out:
# (0.0, 0.3)
